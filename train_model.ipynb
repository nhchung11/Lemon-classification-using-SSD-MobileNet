# %%
# !nvidia-smi
# Out:
# Sat Dec 10 06:39:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    25W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive

# %%
import os
os.chdir("/content/gdrive/MyDrive/Colab Notebooks")
# !ls
# Out:
# Lemon_Final.ipynb  ssd.zip

# %%
# !unzip "/content/gdrive/MyDrive/Colab Notebooks/ssd.zip"
# Out:
# Archive:  /content/gdrive/MyDrive/Colab Notebooks/ssd.zip
#    creating: ssd/
#   inflating: ssd/.git
#   inflating: ssd/.gitignore
#    creating: ssd/.vscode/
#   inflating: ssd/.vscode/settings.json
#    creating: ssd/data/
#    creating: ssd/data/lemon1002/
#    creating: ssd/data/lemon1002/Annotations/
#   inflating: ssd/data/lemon1002/Annotations/IMG_6879.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6881.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6882.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6883.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6884.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6885.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6886.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6887.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6888.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6889.xml
#   inflating: ssd/data/lemon1002/Annotations/IMG_6890.xml
# ...

# %%
os.chdir("/content/gdrive/MyDrive/Colab Notebooks/ssd/")
# !ls
# Out:
# data	     LICENSE	     open_images_downloader.py	run_ssd_example.py
# eval_ssd.py  models	     README.md			train_ssd.py
# labels.txt   onnx_export.py  requirements.txt		vision

# %%
# !wget https://nvidia.box.com/shared/static/djf5w54rjvpqocsiztzaandq1m3avr7c.pth -O models/mobilenet-v1-ssd-mp-0_675.pth
# Out:
# --2022-12-10 06:40:52--  https://nvidia.box.com/shared/static/djf5w54rjvpqocsiztzaandq1m3avr7c.pth
# Resolving nvidia.box.com (nvidia.box.com)... 74.112.186.144
# Connecting to nvidia.box.com (nvidia.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/djf5w54rjvpqocsiztzaandq1m3avr7c.pth [following]
# --2022-12-10 06:40:52--  https://nvidia.box.com/public/static/djf5w54rjvpqocsiztzaandq1m3avr7c.pth
# Reusing existing connection to nvidia.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://nvidia.app.box.com/public/static/djf5w54rjvpqocsiztzaandq1m3avr7c.pth [following]
# --2022-12-10 06:40:52--  https://nvidia.app.box.com/public/static/djf5w54rjvpqocsiztzaandq1m3avr7c.pth
# Resolving nvidia.app.box.com (nvidia.app.box.com)... 74.112.186.144
# Connecting to nvidia.app.box.com (nvidia.app.box.com)|74.112.186.144|:443... connected.
# ...

# %%
import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 1.13.0+cu116
# 0.14.0+cu116

# %%
# !python train_ssd.py --data=data/lemon1002 --model-dir=models/lemon1002 --pretrained-ssd=models/mb1_ssd_fruit.pth --batch-size=64 --num-epochs=100
# Out:
# 2022-12-10 06:41:05 - Using CUDA...
# 2022-12-10 06:41:05 - Namespace(balance_data=False, base_net=None, base_net_lr=0.001, batch_size=64, checkpoint_folder='models/lemon1002', dataset_type='voc', datasets=['data/lemon1002'], debug_steps=10, extra_layers_lr=None, freeze_base_net=False, freeze_net=False, gamma=0.1, lr=0.01, mb2_width_mult=1.0, milestones='80,100', momentum=0.9, net='mb1-ssd', num_epochs=100, num_workers=2, pretrained_ssd='models/mb1_ssd_fruit.pth', resume=None, scheduler='cosine', t_max=100, use_cuda=True, validation_epochs=1, weight_decay=0.0005)
# 2022-12-10 06:41:05 - Prepare training datasets.
# 2022-12-10 06:41:06 - No labels file, using default VOC classes.
# 2022-12-10 06:41:06 - Stored labels into file models/lemon1002/labels.txt.
# 2022-12-10 06:41:06 - Train dataset size: 1002
# 2022-12-10 06:41:06 - Prepare Validation datasets.
# 2022-12-10 06:41:06 - No labels file, using default VOC classes.
# 2022-12-10 06:41:06 - Validation dataset size: 177
# ...

# %%
# !python train_ssd.py --data=data/lemon1002 --model-dir=models/lemon10022 --batch-size=64 --num-epochs=100

# %%
# !pip install onnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python onnx_export.py --input=./models/lemon1002/mb1-ssd-Epoch-97-Loss-0.4151388208071391.pth --output=./models/lemon3.onnx --labels=./models/lemon1002/labels.txt
# Out:
# Namespace(batch_size=1, height=300, input='./models/lemon1002/mb1-ssd-Epoch-97-Loss-0.4151388208071391.pth', labels='./models/lemon1002/labels.txt', model_dir='', net='ssd-mobilenet', output='./models/lemon3.onnx', width=300)
# running on device cuda:0
# creating network:  ssd-mobilenet
# num classes:       3
# loading checkpoint:  ./models/lemon1002/mb1-ssd-Epoch-97-Loss-0.4151388208071391.pth
# exporting model to ONNX...
# Exported graph: graph(%input_0 : Float(1, 3, 300, 300, strides=[270000, 90000, 300, 1], requires_grad=0, device=cuda:0),
#       %extras.0.0.weight : Float(256, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %extras.0.0.bias : Float(256, strides=[1], requires_grad=1, device=cuda:0),
#       %extras.0.2.weight : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %extras.0.2.bias : Float(512, strides=[1], requires_grad=1, device=cuda:0),
# ...
